# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

# %%
img = cv2.imread("brain_mri.jpg")
img_arr = np.array(img)

# %%
plt.imshow(img)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
img_arr_generator = img_arr.reshape((1,) + img_arr.shape)
aug_iter = datagen.flow(img_arr_generator, batch_size=1)

# %%
augmented_image = next(aug_iter)[0]
plt.imshow(augmented_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..243.43835].

# %%
#Otsu's Thresholding
grey_img = cv2.cvtColor(img_arr, cv2.COLOR_BGR2GRAY)
cv2.threshold(grey_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(grey_img, cmap='gray')
